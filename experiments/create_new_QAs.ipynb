# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/multimodal-rag/
# Out:
# /content/drive/MyDrive/multimodal-rag

# %%
# %ls
# Out:
# accepted/             finetuned_qwen_adapter/  requirements.txt
# Create_New_QAs.ipynb  Finetune.ipynb           scripts/
# data/                 generate_custom_data.py
# experiments/          README.md

# %%
# !rm -rf /content/tmp_teacher_model

# %%
# !pip install -r -requierments.txt
# !pip install bitsandbytes
# !pip install qwen_vl_utils
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '-requierments.txt'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 46.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 47.6 MB/s eta 0:00:00
# ...

# %%
! pip install -U "transformers @ git+https://github.com/huggingface/transformers.git" accelerate qwen-vl-utils
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-install-965t5ewj/transformers_2dd6d9bf1cf24eb0b2523f1473146a29
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-install-965t5ewj/transformers_2dd6d9bf1cf24eb0b2523f1473146a29
#   Resolved https://github.com/huggingface/transformers.git to commit c472755e79aac54d675845bff5e5c821c21260af
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-5.7.0.dev0-py3-none-any.whl size=11500397 sha256=9e16d7e2ebe88ec92ab817a4f078fa445f5f1f93b180adf4dae47fa0d9017ee4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j761uvnp/wheels/54/cb/3f/83103de5575c534436d6a4686686dead458238dfaf1147e98d
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
# ...

# %%
# !python generate_custom_data.py \
--input_dir ./accepted \
--out_dir ./accepted \
--doc_type lecture_slides \
--num_questions 1 \
--model_id Qwen/Qwen3-VL-30B-A3B-Instruct \
--local_dir /content/tmp_teacher_model
# Out:
# 2026-04-27 03:31:56,182 - INFO - NumExpr defaulting to 12 threads.
# 2026-04-27 03:31:56,418 - INFO - Loading teacher model: Qwen/Qwen3-VL-30B-A3B-Instruct
# 2026-04-27 03:31:56,418 - INFO - Downloading to ephemeral storage: /content/tmp_teacher_model (Protects GDrive Space)
# --- Local model found at: /content/tmp_teacher_model ---
# --- flash_attention_2 unavailable (ImportError); using sdpa ---
# Loading weights: 100% 882/882 [00:16<00:00, 53.30it/s]
# Processing Images:   0% 0/664 [00:00<?, ?it/s]2026-04-27 03:32:15,721 - INFO - Generating QAs for cd2ee089_p0020.png...
# 2026-04-27 03:32:24,124 - INFO -   -> Kept 1/1 pairs
# Processing Images:   0% 1/664 [00:08<1:32:51,  8.40s/it]2026-04-27 03:32:24,126 - INFO - Generating QAs for cd2ee089_p0001.png...
# 2026-04-27 03:32:28,711 - INFO -   -> Kept 1/1 pairs
# Processing Images:   0% 2/664 [00:12<1:07:57,  6.16s/it]2026-04-27 03:32:28,712 - INFO - Generating QAs for cd2ee089_p0035.png...
# ...
